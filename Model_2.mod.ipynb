# %% [markdown]
# <a href="https://colab.research.google.com/github/Chtholly000/simplified-cnn-fer/blob/main/Model_2.mod.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ==============================================================================
# PART 1: IMPORTS AND SETUP
# ==============================================================================
import os
import pandas as pd
from PIL import Image
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, datasets
import matplotlib.pyplot as plt
from google.colab import files
import zipfile

print("All libraries imported successfully.")

# ==============================================================================
# PART 2: KAGGLE API SETUP & DATA DOWNLOAD
# ==============================================================================
print("\n--- Setting up Kaggle API ---")
if not os.path.exists('/root/.kaggle/kaggle.json'):
    print("Please upload your 'kaggle.json' file:")
    try:
        uploaded = files.upload()
        os.makedirs('/root/.kaggle', exist_ok=True)
        os.rename(list(uploaded.keys())[0], '/root/.kaggle/kaggle.json')
        os.chmod('/root/.kaggle/kaggle.json', 600)
        print("Kaggle API key configured successfully.")
    except Exception as e:
        print(f"\nCould not configure Kaggle API key. Error: {e}")
        exit()
else:
    print("Kaggle API key already exists.")

print("\n--- Downloading FER2013 dataset from Kaggle ---")
DATA_ROOT_DIR = 'fer2013_images'
if not os.path.exists(DATA_ROOT_DIR):
    # !kaggle datasets download -d msambare/fer2013
    print("Unzipping dataset...")
    with zipfile.ZipFile('fer2013.zip', 'r') as zip_ref:
        zip_ref.extractall(DATA_ROOT_DIR)
    print("Dataset unzipped successfully.")
else:
    print("Dataset directory already exists. Skipping download and unzip.")

# ==============================================================================
# PART 3: DATA PREPROCESSING (from Image Folders)
# ==============================================================================
train_transform = transforms.Compose([
    transforms.Grayscale(num_output_channels=1),
    transforms.Resize((48, 48)),
    transforms.RandomRotation(degrees=10),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor()
])
val_transform = transforms.Compose([
    transforms.Grayscale(num_output_channels=1),
    transforms.Resize((48, 48)),
    transforms.ToTensor()
])
print("\nImage folder transforms are defined.")

# ==============================================================================
# PART 4: CNN MODEL 2 DEFINITION
# ==============================================================================
class CnnModel2(nn.Module):
    def __init__(self, num_classes=7):
        super(CnnModel2, self).__init__()
        self.conv_block1 = nn.Sequential(
            nn.Conv2d(1, 64, kernel_size=3, padding=1), nn.ReLU(),
            nn.Conv2d(64, 64, kernel_size=3, padding=1), nn.ReLU(),
            nn.BatchNorm2d(64), nn.MaxPool2d(kernel_size=2, stride=2)
        )
        self.conv_block2 = nn.Sequential(
            nn.Conv2d(64, 128, kernel_size=3, padding=1), nn.ReLU(),
            nn.Conv2d(128, 128, kernel_size=3, padding=1), nn.ReLU(),
            nn.BatchNorm2d(128), nn.MaxPool2d(kernel_size=2, stride=2)
        )
        self.conv_block3 = nn.Sequential(
            nn.Conv2d(128, 256, kernel_size=3, padding=1), nn.ReLU(),
            nn.Conv2d(256, 256, kernel_size=3, padding=1), nn.ReLU(),
            nn.BatchNorm2d(256), nn.MaxPool2d(kernel_size=2, stride=2)
        )
        self.flattened_size = 256 * 6 * 6
        self.classifier = nn.Sequential(
            nn.Linear(self.flattened_size, 256), nn.ReLU(), nn.Dropout(p=0.5),
            nn.Linear(256, 128), nn.ReLU(), nn.Dropout(p=0.5),
            nn.Linear(128, num_classes)
        )
    def forward(self, x):
        x = self.conv_block1(x)
        x = self.conv_block2(x)
        x = self.conv_block3(x)
        x = x.view(-1, self.flattened_size)
        logits = self.classifier(x)
        return logits
print("CNN Model 2 class is defined.")

# ==============================================================================
# PART 5: TRAINING SCRIPT
# ==============================================================================
# --- Configuration ---
NUM_EPOCHS = 100
BATCH_SIZE = 128
LEARNING_RATE = 0.001

# --- Set Device to GPU ---
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# --- Load the FER2013 Data using ImageFolder ---
class_names = []
try:
    train_dir = os.path.join(DATA_ROOT_DIR, 'train')
    val_dir = os.path.join(DATA_ROOT_DIR, 'test')
    train_dataset = datasets.ImageFolder(train_dir, transform=train_transform)
    val_dataset = datasets.ImageFolder(val_dir, transform=val_transform)
    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)
    print(f"\nSuccessfully loaded FER2013 dataset using ImageFolder.")
    print(f"Training set size: {len(train_dataset)}")
    print(f"Validation set size: {len(val_dataset)}")
    class_names = train_dataset.classes
    print(f"Classes found: {class_names}")
except Exception as e:
    print(f"\n--- ERROR LOADING DATA ---")
    print(f"Could not load the dataset from folders. Error: {e}")
    exit()

# --- Instantiate Model, Loss, and Optimizer ---
num_classes = len(class_names)
model = CnnModel2(num_classes=num_classes)
model.to(device)
criterion = nn.CrossEntropyLoss()
print(f"Loss function: {criterion}")
optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE, weight_decay=1e-4)

# --- The Training Loop ---
# Lists to store metrics for plotting
history = {
    'train_loss': [],
    'val_loss': [],
    'val_accuracy': []
}

print("\n--- Starting Training ---")
for epoch in range(NUM_EPOCHS):
    model.train()
    running_loss = 0.0
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
    epoch_loss = running_loss / len(train_loader)
    history['train_loss'].append(epoch_loss)

    # --- Validation Step ---
    model.eval()
    val_loss, correct, total = 0.0, 0, 0
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    val_accuracy = 100 * correct / total
    avg_val_loss = val_loss / len(val_loader)
    history['val_loss'].append(avg_val_loss)
    history['val_accuracy'].append(val_accuracy)

    print(f"Epoch [{epoch+1:02d}/{NUM_EPOCHS}], Train Loss: {epoch_loss:.4f}, Val Loss: {avg_val_loss:.4f}, Val Accuracy: {val_accuracy:.2f}%")

print("--- Finished Training ---")

# ==============================================================================
# PART 6: SAVE AND DOWNLOAD THE TRAINED MODEL
# ==============================================================================
MODEL_SAVE_PATH = 'fer2013_model_2.pth'
print(f"\nSaving model to {MODEL_SAVE_PATH}...")
torch.save(model.state_dict(), MODEL_SAVE_PATH)
print("Model saved successfully.")
print("\nDownloading model file to your local machine...")
files.download(MODEL_SAVE_PATH)

# ==============================================================================
# PART 7: LOAD MODEL AND VISUALIZE PREDICTIONS
# ==============================================================================
print("\n--- Visualizing Model Predictions ---")
loaded_model = CnnModel2(num_classes=num_classes)
loaded_model.load_state_dict(torch.load(MODEL_SAVE_PATH))
loaded_model.to(device)
loaded_model.eval()
images, labels = next(iter(val_loader))
images, labels = images.to(device), labels.to(device)
with torch.no_grad():
    outputs = loaded_model(images)
    _, predicted = torch.max(outputs, 1)
images = images.cpu()
labels = labels.cpu()
predicted = predicted.cpu()
fig = plt.figure(figsize=(15, 10))
for i in range(min(len(images), 16)):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    img = images[i].squeeze()
    ax.imshow(img, cmap='gray')
    true_label = class_names[labels[i]]
    pred_label = class_names[predicted[i]]
    title_color = 'g' if true_label == pred_label else 'r'
    ax.set_title(f"True: {true_label}\nPred: {pred_label}", color=title_color)
plt.tight_layout()
plt.show()

# ==============================================================================
# PART 8: PLOT TRAINING HISTORY
# This new part visualizes the training progress.
# ==============================================================================
print("\n--- Plotting Training History ---")
epochs = range(1, NUM_EPOCHS + 1)

# Plot 1: Training and Validation Loss
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs, history['train_loss'], 'b-', label='Training Loss')
plt.plot(epochs, history['val_loss'], 'r-', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

# Plot 2: Validation Accuracy
plt.subplot(1, 2, 2)
plt.plot(epochs, history['val_accuracy'], 'g-', label='Validation Accuracy')
plt.title('Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# All libraries imported successfully.
#
# --- Setting up Kaggle API ---
# Kaggle API key already exists.
#
# --- Downloading FER2013 dataset from Kaggle ---
# Dataset directory already exists. Skipping download and unzip.
#
# Image folder transforms are defined.
# CNN Model 2 class is defined.
# Using device: cuda
#
# Successfully loaded FER2013 dataset using ImageFolder.
# Training set size: 28709
# Validation set size: 7178
# Classes found: ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']
# Loss function: CrossEntropyLoss()
#
# --- Starting Training ---
# Epoch [01/100], Train Loss: 1.8042, Val Loss: 1.6009, Val Accuracy: 34.87%
# Epoch [02/100], Train Loss: 1.5877, Val Loss: 1.5517, Val Accuracy: 40.83%
# Epoch [03/100], Train Loss: 1.4403, Val Loss: 1.3450, Val Accuracy: 48.58%
# Epoch [04/100], Train Loss: 1.3597, Val Loss: 1.2960, Val Accuracy: 50.40%
# Epoch [05/100], Train Loss: 1.2901, Val Loss: 1.2208, Val Accuracy: 53.09%
# Epoch [06/100], Train Loss: 1.2383, Val Loss: 1.2155, Val Accuracy: 53.02%
# Epoch [07/100], Train Loss: 1.2008, Val Loss: 1.1788, Val Accuracy: 55.45%
# Epoch [08/100], Train Loss: 1.1658, Val Loss: 1.0929, Val Accuracy: 58.67%
# Epoch [09/100], Train Loss: 1.1345, Val Loss: 1.0809, Val Accuracy: 59.19%
# Epoch [10/100], Train Loss: 1.1068, Val Loss: 1.0863, Val Accuracy: 58.94%
# Epoch [11/100], Train Loss: 1.0737, Val Loss: 1.0671, Val Accuracy: 59.79%
# Epoch [12/100], Train Loss: 1.0616, Val Loss: 1.0328, Val Accuracy: 61.13%
# Epoch [13/100], Train Loss: 1.0398, Val Loss: 1.0461, Val Accuracy: 60.59%
# Epoch [14/100], Train Loss: 1.0175, Val Loss: 1.0118, Val Accuracy: 61.42%
# Epoch [15/100], Train Loss: 0.9968, Val Loss: 1.0231, Val Accuracy: 61.56%
# Epoch [16/100], Train Loss: 0.9736, Val Loss: 1.0024, Val Accuracy: 62.54%
# Epoch [17/100], Train Loss: 0.9587, Val Loss: 1.0025, Val Accuracy: 62.47%
# Epoch [18/100], Train Loss: 0.9482, Val Loss: 0.9934, Val Accuracy: 62.58%
# Epoch [19/100], Train Loss: 0.9287, Val Loss: 1.0107, Val Accuracy: 62.11%
# Epoch [20/100], Train Loss: 0.9105, Val Loss: 0.9747, Val Accuracy: 63.83%
# Epoch [21/100], Train Loss: 0.8882, Val Loss: 0.9746, Val Accuracy: 63.92%
# Epoch [22/100], Train Loss: 0.8767, Val Loss: 1.0035, Val Accuracy: 62.91%
# Epoch [23/100], Train Loss: 0.8499, Val Loss: 0.9823, Val Accuracy: 64.24%
# Epoch [24/100], Train Loss: 0.8408, Val Loss: 0.9794, Val Accuracy: 63.88%
# Epoch [25/100], Train Loss: 0.8279, Val Loss: 0.9693, Val Accuracy: 64.17%
# Epoch [26/100], Train Loss: 0.8062, Val Loss: 1.0061, Val Accuracy: 63.88%
# Epoch [27/100], Train Loss: 0.8058, Val Loss: 0.9892, Val Accuracy: 64.88%
# Epoch [28/100], Train Loss: 0.7823, Val Loss: 0.9978, Val Accuracy: 64.70%
# Epoch [29/100], Train Loss: 0.7806, Val Loss: 1.0243, Val Accuracy: 64.11%
# Epoch [30/100], Train Loss: 0.7604, Val Loss: 1.0065, Val Accuracy: 63.67%
# Epoch [31/100], Train Loss: 0.7496, Val Loss: 0.9938, Val Accuracy: 64.71%
# Epoch [32/100], Train Loss: 0.7313, Val Loss: 1.0207, Val Accuracy: 64.71%
# Epoch [33/100], Train Loss: 0.7273, Val Loss: 1.0596, Val Accuracy: 63.29%
# Epoch [34/100], Train Loss: 0.7123, Val Loss: 1.0201, Val Accuracy: 64.82%
# Epoch [35/100], Train Loss: 0.7078, Val Loss: 1.0508, Val Accuracy: 64.80%
# Epoch [36/100], Train Loss: 0.6864, Val Loss: 1.0369, Val Accuracy: 65.27%
# Epoch [37/100], Train Loss: 0.6785, Val Loss: 1.0338, Val Accuracy: 64.86%
# Epoch [38/100], Train Loss: 0.6590, Val Loss: 1.0573, Val Accuracy: 65.10%
# Epoch [39/100], Train Loss: 0.6632, Val Loss: 1.0405, Val Accuracy: 65.41%
# Epoch [40/100], Train Loss: 0.6505, Val Loss: 1.0610, Val Accuracy: 64.89%
# Epoch [41/100], Train Loss: 0.6313, Val Loss: 1.0578, Val Accuracy: 65.52%
# Epoch [42/100], Train Loss: 0.6397, Val Loss: 1.0526, Val Accuracy: 64.64%
# Epoch [43/100], Train Loss: 0.6153, Val Loss: 1.0295, Val Accuracy: 65.77%
# Epoch [44/100], Train Loss: 0.6074, Val Loss: 1.0557, Val Accuracy: 66.41%
# Epoch [45/100], Train Loss: 0.6035, Val Loss: 1.0961, Val Accuracy: 65.42%
# Epoch [46/100], Train Loss: 0.5925, Val Loss: 1.0570, Val Accuracy: 65.84%
# Epoch [47/100], Train Loss: 0.5823, Val Loss: 1.1153, Val Accuracy: 65.28%
# Epoch [48/100], Train Loss: 0.5774, Val Loss: 1.0793, Val Accuracy: 65.62%
# Epoch [49/100], Train Loss: 0.5787, Val Loss: 1.0744, Val Accuracy: 65.99%
# Epoch [50/100], Train Loss: 0.5643, Val Loss: 1.1011, Val Accuracy: 65.73%
# Epoch [51/100], Train Loss: 0.5574, Val Loss: 1.0972, Val Accuracy: 65.88%
# Epoch [52/100], Train Loss: 0.5448, Val Loss: 1.1195, Val Accuracy: 65.59%
# Epoch [53/100], Train Loss: 0.5399, Val Loss: 1.1431, Val Accuracy: 66.24%
# Epoch [54/100], Train Loss: 0.5280, Val Loss: 1.1154, Val Accuracy: 65.41%
# Epoch [55/100], Train Loss: 0.5294, Val Loss: 1.1522, Val Accuracy: 65.60%
# Epoch [56/100], Train Loss: 0.5232, Val Loss: 1.1122, Val Accuracy: 65.70%
# Epoch [57/100], Train Loss: 0.5197, Val Loss: 1.1164, Val Accuracy: 65.60%
# Epoch [58/100], Train Loss: 0.5080, Val Loss: 1.1194, Val Accuracy: 65.60%
# Epoch [59/100], Train Loss: 0.5063, Val Loss: 1.1280, Val Accuracy: 65.32%
# Epoch [60/100], Train Loss: 0.4935, Val Loss: 1.2096, Val Accuracy: 65.05%
# Epoch [61/100], Train Loss: 0.4943, Val Loss: 1.1452, Val Accuracy: 65.95%
# Epoch [62/100], Train Loss: 0.4895, Val Loss: 1.1381, Val Accuracy: 65.65%
# Epoch [63/100], Train Loss: 0.4820, Val Loss: 1.2070, Val Accuracy: 65.24%
# Epoch [64/100], Train Loss: 0.4769, Val Loss: 1.1887, Val Accuracy: 65.85%
# Epoch [65/100], Train Loss: 0.4825, Val Loss: 1.1608, Val Accuracy: 66.54%
# Epoch [66/100], Train Loss: 0.4709, Val Loss: 1.1984, Val Accuracy: 66.45%
# Epoch [67/100], Train Loss: 0.4614, Val Loss: 1.2180, Val Accuracy: 65.41%
# Epoch [68/100], Train Loss: 0.4654, Val Loss: 1.2147, Val Accuracy: 66.15%
# Epoch [69/100], Train Loss: 0.4486, Val Loss: 1.2273, Val Accuracy: 65.90%
# Epoch [70/100], Train Loss: 0.4433, Val Loss: 1.2484, Val Accuracy: 65.39%
# Epoch [71/100], Train Loss: 0.4545, Val Loss: 1.1941, Val Accuracy: 66.51%
# Epoch [72/100], Train Loss: 0.4433, Val Loss: 1.2580, Val Accuracy: 65.90%
# Epoch [73/100], Train Loss: 0.4360, Val Loss: 1.2293, Val Accuracy: 66.61%
# Epoch [74/100], Train Loss: 0.4361, Val Loss: 1.3012, Val Accuracy: 65.27%
# Epoch [75/100], Train Loss: 0.4300, Val Loss: 1.2156, Val Accuracy: 65.91%
# Epoch [76/100], Train Loss: 0.4229, Val Loss: 1.2412, Val Accuracy: 66.04%
# Epoch [77/100], Train Loss: 0.4205, Val Loss: 1.2585, Val Accuracy: 66.15%
# Epoch [78/100], Train Loss: 0.4179, Val Loss: 1.2586, Val Accuracy: 65.58%
# Epoch [79/100], Train Loss: 0.4163, Val Loss: 1.2594, Val Accuracy: 65.42%
# Epoch [80/100], Train Loss: 0.4185, Val Loss: 1.2992, Val Accuracy: 64.93%
# Epoch [81/100], Train Loss: 0.4051, Val Loss: 1.2659, Val Accuracy: 65.41%
# Epoch [82/100], Train Loss: 0.4130, Val Loss: 1.3187, Val Accuracy: 65.42%
# Epoch [83/100], Train Loss: 0.4074, Val Loss: 1.3113, Val Accuracy: 64.96%
# Epoch [84/100], Train Loss: 0.4024, Val Loss: 1.3363, Val Accuracy: 65.71%
# Epoch [85/100], Train Loss: 0.4056, Val Loss: 1.3102, Val Accuracy: 64.85%
# Epoch [86/100], Train Loss: 0.4049, Val Loss: 1.2770, Val Accuracy: 65.67%
# Epoch [87/100], Train Loss: 0.3853, Val Loss: 1.3276, Val Accuracy: 64.80%
# Epoch [88/100], Train Loss: 0.3853, Val Loss: 1.3029, Val Accuracy: 66.37%
# Epoch [89/100], Train Loss: 0.3944, Val Loss: 1.3247, Val Accuracy: 66.91%
# Epoch [90/100], Train Loss: 0.3770, Val Loss: 1.3497, Val Accuracy: 66.17%
# Epoch [91/100], Train Loss: 0.3859, Val Loss: 1.3635, Val Accuracy: 65.77%
# Epoch [92/100], Train Loss: 0.3713, Val Loss: 1.2936, Val Accuracy: 66.29%
# Epoch [93/100], Train Loss: 0.3834, Val Loss: 1.3429, Val Accuracy: 65.35%
# Epoch [94/100], Train Loss: 0.3789, Val Loss: 1.3647, Val Accuracy: 65.84%
# Epoch [95/100], Train Loss: 0.3779, Val Loss: 1.3546, Val Accuracy: 66.45%
# Epoch [96/100], Train Loss: 0.3737, Val Loss: 1.2975, Val Accuracy: 65.20%
# Epoch [97/100], Train Loss: 0.3781, Val Loss: 1.4377, Val Accuracy: 66.04%
# Epoch [98/100], Train Loss: 0.3683, Val Loss: 1.3315, Val Accuracy: 66.68%
# Epoch [99/100], Train Loss: 0.3716, Val Loss: 1.3243, Val Accuracy: 66.10%
# Epoch [100/100], Train Loss: 0.3710, Val Loss: 1.3523, Val Accuracy: 66.05%
# --- Finished Training ---
#
# Saving model to fer2013_model_2.pth...
# Model saved successfully.
#
# Downloading model file to your local machine...
# --- Visualizing Model Predictions ---
# --- Plotting Training History ---
